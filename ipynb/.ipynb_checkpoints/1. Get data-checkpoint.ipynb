# %%
import glob
import pandas as pd
import gzip
import urllib.request
import codecs

from helpers import *

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/vecht499/anaconda/envs/py35/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Get the data

# %% [markdown]
# From https://archive.org/download/amazon-reviews-1995-2013 we will download:
# - gourmet foods
# - pet supplies
# - home&kitchen
# - beauty
# - health
# - baby
#
# Plus we will need all categories metadata

# %%
## It takes a while!
list_to_download = ['Gourmet_Foods','Pet_Supplies','Home_&_Kitchen','Beauty','Health','Baby','categories']

for i in list_to_download:
    if i in [x.split('data/')[1].split('.txt')[0] for x in glob.glob('../data/*')]:
        print("File {} is already downloaded".format(i))
    else:
        f = urllib.request.urlopen('https://archive.org/download/amazon-reviews-1995-2013/'+i+'.txt.gz')
        data = f.read()
        with open('../data/'+i+'.txt.gz', 'wb') as code:
            code.write(data)
            code.close()

        g = gzip.open('../data/'+i+'.txt.gz', 'rb')
        with open('../data/'+i+'.txt', 'wb') as outfile:
            for line in g:
                outfile.write(line)
            outfile.close()
        print("File {} is downloaded".format(i))
# Out:
# File Gourmet_Foods is already downloaded
# File Pet_Supplies is already downloaded
# File Home_&_Kitchen is already downloaded
# File Beauty is already downloaded
# File Health is already downloaded
# File Baby is already downloaded
# File categories is already downloaded

# %%
df_list = []

for file in list_to_download[0:6]:
    
    with open('../data/'+file+'.txt', 'r') as f:
        reviews = f.read()
    
    reviews_list = reviews.split('\n\n')
    headers= ['productId','Title','userId','Helpfulness','Score','Text']

    all_records = []
    ## the last record is empty
    for i in range(len(reviews_list)-1):
        record = [reviews_list[i].split('\n')[0].split(': ')[1],
                  reviews_list[i].split('\n')[1].split(': ')[1],
                  reviews_list[i].split('\n')[3].split(': ')[1],
                  reviews_list[i].split('\n')[5].split(': ')[1],
                  reviews_list[i].split('\n')[6].split(': ')[1],
                  reviews_list[i].split('\n')[9].split(': ')[1]]
        all_records.append(record)
    
    df = pd.DataFrame(all_records, columns=headers)
    if file=='Home_&_Kitchen':
        df = df.sample(frac=0.5).copy()
    df_list.append(df)
    
df_reviews = pd.concat(df_list)

# %%
with codecs.open('../data/categories.txt', "r", "latin_1") as f:
    categories = f.read()
    
categories_list = categories.split('\n')
headers= ['productId','Cat1','Cat2','Cat3']

all_records = []
for i in range(len(categories_list)):
    if 'B00' in categories_list[i-1]:
        record = [categories_list[i-1]] + categories_list[i].split(", ")
        if len(record)<4:
            record = record+['Unknown']*(4-len(record))
        else:
            record = record[0:4]
        all_records.append(record) 
            
df_categories = pd.DataFrame(all_records, columns=headers)

# %%
df = df_reviews.merge(df_categories, on="productId", how='inner')

# %% [markdown]
# ## Look at the data

# %%
df.head()
# Out:
#     productId                                              Title  \
# 0  B000EVS4TY  Arrowhead Mills Cookie Mix, Chocolate Chip, 12...
# 1  B0000DF3IX                            Paprika Hungarian Sweet
# 2  B0002QF1LK        Quaker Honey Graham Oh's 10.5 oz - (6 pack)
# 3  B0002QF1LK        Quaker Honey Graham Oh's 10.5 oz - (6 pack)
# 4  B0002QF1LK        Quaker Honey Graham Oh's 10.5 oz - (6 pack)
#
#            userId Helpfulness Score  \
# 0  A2SRVDDDOQ8QJL         2/4   4.0
# 1  A244MHL2UN2EYL         0/0   5.0
# 2  A3FL7SXVYMC5NR         3/3   5.0
# 3  A12IDQSS4OW33B         3/3   5.0
# 4  A2GZKHC1M4PKF4         2/2   3.0
#
#                                                 Text  \
# 0  I thought it was funny that I bought this prod...
# 1  While in Hungary we were given a recipe for Hu...
# 2  Without a doubt, I would recommend this wholes...
# 3  This cereal is so sweet....yet so good for you...
# 4  Man I love Oh's cereal. It is really great to ...
#
#                        Cat1                       Cat2                 Cat3
# 0    Grocery & Gourmet Food  Cooking & Baking Supplies         Baking Mixes
# 1    Grocery & Gourmet Food                      Herbs  Spices & Seasonings
# 2    Grocery & Gourmet Food            Breakfast Foods              Cereals
# 3    Grocery & Gourmet Food            Breakfast Foods              Cereals
# 4    Grocery & Gourmet Food            Breakfast Foods              Cereals

# %%
len(df)
# Out:
# 2228809

# %%
## drop duplicates
df = df.drop_duplicates().copy().reset_index(drop=True)
## remove nan reviews
df = df[pd.notnull(df.Text)].reset_index(drop=True).copy()

# %%
len(df)
# Out:
# 2186741

# %%
df['Cat1'] = df['Cat1'].apply(lambda x: cleanData(x))
df['Cat2'] = df['Cat2'].apply(lambda x: cleanData(x))
df['Cat3'] = df['Cat3'].apply(lambda x: cleanData(x))

# %%
plt.figure(figsize=(10,15))
sns.countplot(y='Cat1', data=df)

# %% [markdown]
# ## Modify dataset

# %%
len(df[(df.Cat1 == ' home  kitchen')|(df.Cat1 == ' health  personal care')|(df.Cat1 == ' pet supplies') \
       |(df.Cat1 == ' baby products') |(df.Cat1 == ' beauty')|(df.Cat1 == ' grocery  gourmet food')])
# Out:
# 2152031

# %% [markdown]
# It makes sense to only take the categories which occur often. Also, we will put together categories such as **snack food** and **snack foods**, **candy**, **candy chocolate**, **chocolate**

# %%
df_mod = df[(df.Cat1 == ' home  kitchen')|(df.Cat1 == ' health  personal care')|(df.Cat1 == ' pet supplies') \
            |(df.Cat1 == ' baby products') |(df.Cat1 == ' beauty')\
            |(df.Cat1 == ' grocery  gourmet food')].reset_index(drop=True).copy()

# %%
plt.figure(figsize=(10,15))
sns.countplot(y='Cat1', data=df_mod)

# %%
df_mod[df_mod.Cat2=='kitchen  dining'].Cat3.value_counts()
# Out:
# small appliances                       140698
# kitchen utensils  gadgets              102394
# cookware                                70119
# coffee                                  68468
# bakeware                                44674
# tabletop                                39954
# kitchen knives  cutlery accessories     33331
# storage  organization                   26686
# small appliance parts  accessories      18703
# unknown                                 13053
# glassware  drinkware                    10512
# kitchen  table linens                    7663
# water coolers  filters                   7144
# bar tools  glasses                       6506
# home brewing  wine making                1302
# wine accessories                           95
# food service equipment  supplies           20
# Name: Cat3, dtype: int64

# %%
df_mod[df_mod.Cat1==' home  kitchen'].Cat2.unique()
# Out:
# array(['kitchen  dining', 'home d cor', 'heating', 'bath', 'artwork',
#        'bedding', 'storage  organization', 'vacuums  floor care',
#        'furniture', 'unknown', 'seasonal d cor', 'irons  steamers',
#        'cleaning supplies', 'kids home store'], dtype=object)

# %%
plt.figure(figsize=(10,15))
sns.countplot(y='Cat2', data=df_mod)

# %%
## put together some categories:
df_mod["Cat2"] = df_mod["Cat2"].apply(lambda x: 'candy chocolate' if x=='candy'
                                                 else 'candy chocolate' if x=='candy  chocolate'
                                                 else 'candy chocolate' if x=='chocolate'
                                                 else 'snack food' if x=='snack foods'
                                                 else x)

# %%
## remove Unknown
df_mod = df_mod[df_mod.Cat2 != 'unknown'].reset_index(drop=True).copy()

## remove pet supplies international shipping available
df_mod = df_mod[df_mod.Cat2 !='pet supplies international shipping available'].reset_index(drop=True).copy()

# %%
## remove products that occur only once
s = pd.DataFrame(df_mod.Title.value_counts())
df_mod = df_mod[df_mod.Title.isin(s[s.Title==1].index.tolist()) == False].reset_index(drop=True).copy()

## remove Cat2 that occur less than 200 tim
s = pd.DataFrame(df_mod.Cat2.value_counts())
df_mod = df_mod[df_mod.Cat2.isin(s[s.Cat2<400].index.tolist()) == False].reset_index(drop=True).copy()

# %%
plt.figure(figsize=(10,15))
sns.countplot(y='Cat2', data=df_mod)

# %%
for i in df_mod.Cat1.unique().tolist():
    print(i, df_mod[df_mod.Cat1 == i].Cat2.unique())
# Out:
#  grocery  gourmet food ['herbs' 'breakfast foods' 'candy chocolate' 'dairy  eggs' 'pantry staples'
#  'beverages' 'meat  poultry' 'baby food' 'snack food' 'oils'
#  'beans  grains' 'dairy' 'prepared food' 'seafood' 'meat  seafood'
#  'sauces  dips' 'breads  bakery' 'baby foods' 'cooking  baking supplies'
#  'gourmet gifts' 'fresh flowers  live indoor plants' 'produce']
#  beauty ['bath  body' 'skin care' 'tools  accessories' 'hair care' 'fragrance'
#  'makeup']
#  baby products ['diapering' 'feeding' 'safety' 'potty training' 'nursery' 'gear'
#  'bathing  skin care' 'gifts' 'health  baby care' 'strollers'
#  'car seats  accessories' 'pregnancy  maternity']
#  pet supplies ['dogs' 'fish  aquatic pets' 'cats' 'birds' 'reptiles  amphibians'
#  'bunny rabbit central' 'hagen' 'small animals']
#  health  personal care ['health care' 'nutrition  wellness' 'personal care'
#  'medical supplies  equipment' 'household supplies'
#  'stationery  party supplies' 'sexual wellness' 'baby  child care']
#  home  kitchen ['kitchen  dining' 'heating' 'bath' 'home d cor' 'bedding'
#  'storage  organization' 'artwork' 'vacuums  floor care' 'furniture'
#  'seasonal d cor' 'irons  steamers']

# %%
len(df_mod)
# Out:
# 2037469

# %%
df_mod.head()
# Out:
#     productId                                        Title          userId  \
# 0  B0000DF3IX                      Paprika Hungarian Sweet  A244MHL2UN2EYL
# 1  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)  A3FL7SXVYMC5NR
# 2  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)  A12IDQSS4OW33B
# 3  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)  A2GZKHC1M4PKF4
# 4  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)   AUGT2DOGKLHIN
#
#   Helpfulness Score                                               Text  \
# 0         0/0   5.0  While in Hungary we were given a recipe for Hu...
# 1         3/3   5.0  Without a doubt, I would recommend this wholes...
# 2         3/3   5.0  This cereal is so sweet....yet so good for you...
# 3         2/2   3.0  Man I love Oh's cereal. It is really great to ...
# 4         2/2   5.0  And I've tried alot of cereals. This is by far...
#
#                      Cat1             Cat2                Cat3
# 0   grocery  gourmet food            herbs  spices  seasonings
# 1   grocery  gourmet food  breakfast foods             cereals
# 2   grocery  gourmet food  breakfast foods             cereals
# 3   grocery  gourmet food  breakfast foods             cereals
# 4   grocery  gourmet food  breakfast foods             cereals

# %%
df_mod.Title.value_counts()
# Out:
# Renaissance 600 Thread Count 100% Cotton Sateen Sheet Set                                               13438
# Pampers Baby Dry Diapers (Packaging May Vary)                                                           10189
# China Glaze Nail Lacquer with Hardeners                                                                  5771
# My Lip Stuff- Tube - Over 600 Lipbalm Flavors Available                                                  5418
# FURminator deShedding Tool                                                                               4728
# Crane Adorable 1 Gallon Cool Mist Humidifier                                                             3890
# Amazon.com                                                                                               3712
# KitchenAid Professional 600 Series 6-Quart Stand Mixer                                                   3704
# Pampers Cruisers Diapers                                                                                 3568
# Cuisinart DCC-1200 Brew Central 12-Cup Programmable Coffeemaker                                          3421
