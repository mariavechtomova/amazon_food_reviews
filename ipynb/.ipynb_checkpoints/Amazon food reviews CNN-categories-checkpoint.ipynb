# %% [markdown]
# ## CNN text classification on Amazon food reviews
#
# Literature on CNNs for NLP tasks:
#
# 1) http://www.wildml.com/2015/11/understanding-convolutional-neural-networks-for-nlp/
#
# 2) https://arxiv.org/pdf/1404.2188.pdf
#
# 3) https://arxiv.org/pdf/1408.5882.pdf
#
# 4) http://cs224d.stanford.edu/reports/RhodesDylan.pdf
#
# 5) http://cs224d.stanford.edu/reports/DufourNick.pdf
#
#
# Word2vec explained:
# - http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
# - http://stats.stackexchange.com/questions/244616/how-sampling-works-in-word2vec-can-someone-please-make-me-understand-nce-and-ne/245452#245452
#
# How to use tensorboard:
# - http://ischlag.github.io/2016/06/04/how-to-use-tensorboard/
#
# Inspired by:
# - http://www.wildml.com/2015/12/implementing-a-cnn-for-text-classification-in-tensorflow/
# - https://agarnitin86.github.io/blog/2016/12/23/text-classification-cnn

# %%
import pandas as pd
from helpers import *

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from nltk import FreqDist
import operator
import numpy as np

from sklearn.model_selection import train_test_split

import tensorflow as tf
# Out:
# /home/vecht499/anaconda/envs/py35/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == labels) / predictions.shape[0])

# %% [markdown]
# ## Load dataset & process it

# %%
df = pd.read_csv("../data/Reviews.csv")
df.columns = map(lambda x: x.lower(), df.columns)

# %%
df["text"] = df["text"].apply(lambda x: cleanData(x))
df["text_length"] = df["text"].apply(lambda x: getSentenceLength(x))

# %%
## review length distribution
plt.figure(figsize=(15,8))
sns.kdeplot(df.text_length, shade=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106529 entries, 0 to 106528
# Data columns (total 10 columns):
# productid      106529 non-null object
# title          106511 non-null object
# userid         106529 non-null object
# helpfulness    106529 non-null object
# score          106529 non-null float64
# text           106529 non-null object
# cat1           106529 non-null object
# cat2           106529 non-null object
# cat3           106529 non-null object
# text_length    106529 non-null int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 8.1+ MB

# %%
## remove reviews with length more than 100
df = df[df.text_length<=100].copy()
## if length of a review is shorter than 100; fill it in with placeholer words
df["text_adj"] = df["text"].apply(lambda x: add_placeholders(x, 100))

# %%
df.head(2)
# Out:
#     productid                                        title          userid  \
# 0  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)  A3FL7SXVYMC5NR
# 3  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)   AUGT2DOGKLHIN
#
#   helpfulness  score                                               text  \
# 0         3/3    5.0  without a doubt i would recommend this wholeso...
# 3         2/2    5.0  and i ve tried alot of cereals this is by far ...
#
#                        cat1             cat2     cat3  text_length  \
# 0    Grocery & Gourmet Food  breakfast foods  cereals           38
# 3    Grocery & Gourmet Food  breakfast foods  cereals           43
#
#                                             text_adj
# 0  without a doubt i would recommend this wholeso...
# 3  and i ve tried alot of cereals this is by far ...

# %%
## create word count dictionary for all reviews
word_dist = FreqDist()
for s in df.text_adj:
    word_dist.update(s.split())

## replace rare words (occur only once)
words_to_replace = [k for k, v in dict(word_dist).items() if v == 1]

word_lookup = dict()
for word in dict(word_dist).keys():
    if word in words_to_replace:
        word_lookup[word] = "rarewordplaceholder"
    else:
        word_lookup[word] = word

def replace_words(strg, words_to_replace):
    line = strg.split()
    line = [word_lookup[x] for x in line]
    result = ' '.join(line)
    return result

df["text_adj"] = df["text_adj"].apply(lambda x: replace_words(x, words_to_replace))

# %%
## create word count dictionary for all reviews
word_dist = FreqDist()
for s in df.text_adj:
    word_dist.update(s.split())

## take a look at dictionary
sorted_x = sorted(dict(word_dist).items(), key=operator.itemgetter(1))
print(sorted_x)
# Out:
# [('tspns', 2), ('referrals', 2), ('showcased', 2), ('phew', 2), ('ironbeer', 2), ('restuarants', 2), ('nubs', 2), ('lieferung', 2), ('bloomberg', 2), ('timei', 2), ('overstocked', 2), ('ozi', 2), ('stapler', 2), ('gloves', 2), ('movin', 2), ('populate', 2), ('hubbie', 2), ('marietta', 2), ('chateau', 2), ('grapenuts', 2), ('dashed', 2), ('meadowood', 2), ('jody', 2), ('meyers', 2), ('attendent', 2), ('rs', 2), ('activates', 2), ('butterfat', 2), ('goodearth', 2), ('horny', 2), ('bearito', 2), ('pachage', 2), ('sleek', 2), ('lesst', 2), ('tending', 2), ('shortbreads', 2), ('ording', 2), ('ons', 2), ('variances', 2), ('composted', 2), ('insensitive', 2), ('envy', 2), ('repeatable', 2), ('overbrew', 2), ('byrd', 2), ('astronomically', 2), ('membranes', 2), ('confession', 2), ('loveeee', 2), ('mantra', 2), ('reginald', 2), ('midafternoon', 2), ('yakisoba', 2), ('approves', 2), ('muggy', 2), ('mccutcheons', 2), ('drumsticks', 2), ('bhutan', 2), ('comercially', 2), ('flavenoids', 2), ('macchiato', 2), ('nightquil', 2), ('ryvitas', 2), ('shhhhh', 2), ('winey', 2), ('overflows', 2), ('slack', 2), ('dammage', 2), ('athens', 2), ('tillamuck', 2), ('grouper', 2), ('unnecessarily', 2), ('xl', 2), ('reinbursed', 2), ('jerked', 2), ('pizzerias', 2), ('vick', 2), ('saly', 2), ('ginko', 2), ('oliver', 2), ('lesaffre', 2), ('tuaca', 2), ('didnot', 2), ('pulpy', 2), ('popcorm', 2), ('phased', 2), ('mow', 2), ('soit', 2), ('freen', 2), ('resplendent', 2), ('antacid', 2), ('responsibly', 2), ('wat', 2), ('youstephanie', 2), ('rotated', 2), ('barton', 2), ('crackling', 2), ('reset', 2), ('hich', 2), ('wasthat', 2), ('tinkering', 2), ('yummypat', 2), ('kosciusko', 2), ('fattier', 2), ('sass', 2), ('grocerys', 2), ('marcia', 2), ('fari', 2), ('trenton', 2), ('maranatha', 2), ('freshand', 2), ('coffeei', 2), ('inexplicably', 2), ('yipee', 2), ('polluting', 2), ('obnoxiously', 2), ('immer', 2), ('greesy', 2), ('jolted', 2), ('recipiant', 2), ('barr', 2), ('dramamine', 2), ('doomur', 2), ('distinction', 2), ('cubyrop', 2), ('shellac', 2), ('context', 2), ('passage', 2), ('soury', 2), ('interchangably', 2), ('flood', 2), ('escaped', 2), ('cearal', 2), ('spanning', 2), ('boxs', 2), ('sux', 2), ('overcomes', 2), ('froths', 2), ('leaders', 2), ('felling', 2), ('purcased', 2), ('chaser', 2), ('jemima', 2), ('dank', 2), ('pcos', 2), ('narrowed', 2), ('snax', 2), ('thinkof', 2), ('ergo', 2), ('lottery', 2), ('quaity', 2), ('esque', 2), ('revving', 2), ('overpaying', 2), ('unparalleled', 2), ('blocs', 2), ('synagogue', 2), ('bookstore', 2), ('outraged', 2), ('macrobiotics', 2), ('esq', 2), ('judicious', 2), ('oster', 2), ('brank', 2), ('absoultely', 2), ('postpartum', 2), ('transactions', 2), ('begluten', 2), ('observe', 2), ('hoops', 2), ('darken', 2), ('counterbalanced', 2), ('revise', 2), ('ani', 2), ('twiggy', 2), ('checkouts', 2), ('indoor', 2), ('yummmmmmmmmmm', 2), ('chilie', 2), ('kajun', 2), ('vitaminwater', 2), ('lumping', 2), ('coffeeshop', 2), ('jackass', 2), ('packo', 2), ('tahiti', 2), ('skinned', 2), ('najjar', 2), ('keychains', 2), ('scrimp', 2), ('sandwichs', 2), ('vermicelli', 2), ('acesulfame', 2), ('vol', 2), ('notches', 2), ('producto', 2), ('behalf', 2), ('rowntree', 2), ('innocently', 2), ('yip', 2), ('congress', 2), ('screens', 2), ('preferance', 2), ('vrey', 2), ('immitations', 2), ('hih', 2), ('ts', 2), ('thesugar', 2), ('alterations', 2), ('parmigiano', 2), ('longshot', 2), ('cysts', 2), ('slips', 2), ('contradictory', 2), ('intentions', 2), ('caramelos', 2), ('sweatner', 2), ('hokey', 2), ('memeories', 2), ('drake', 2), ('recaito', 2), ('folds', 2), ('pendleton', 2), ('glutamic', 2), ('weep', 2), ('imbue', 2), ('comprising', 2), ('canine', 2), ('extracting', 2), ('yearned', 2), ('dismembered', 2), ('scotia', 2), ('wah', 2), ('rood', 2), ('sabotage', 2), ('chocloate', 2), ('beggars', 2), ('godzilla', 2), ('mackeral', 2), ('influenced', 2), ('perrrrrrfect', 2), ('ovens', 2), ('instruct', 2), ('afficionados', 2), ('learnt', 2), ('preve ...

# %%
vocab = dict()
for e,y in enumerate(dict(word_dist).keys()):
    vocab[y]=e

# %%
len(vocab)
# Out:
# 20889

# %%
vocab
# Out:
# {'tmnt': 10430,
#  'nursery': 10431,
#  'misinformation': 8,
#  'molars': 1,
#  'pests': 15989,
#  'power': 2,
#  'tspns': 3,
#  'bribery': 4,
#  'marginally': 10434,
#  'listing': 5,
#  'economically': 6,
#  'sounding': 10436,
#  'acidity': 7,
#  'celtic': 0,
#  'baste': 10439,
#  'ends': 10440,
#  'adkins': 12135,
#  'approximation': 17080,
#  'gentlemen': 10441,
#  'sweetish': 10442,
#  'snickerdoodles': 58,
#  'wits': 16858,
#  'puy': 9,
#  'intensely': 19517,
#  'referrals': 10,
#  'oatstraw': 17416,
#  'erewhon': 10445,
#  'ozi': 86,
#  'cheaper': 12,
#  'jigger': 10446,
#  'tact': 13,
#  'melissa': 14,
#  'translation': 10447,
#  'tgfop': 14752,
#  'priceless': 15,
#  'authentic': 10448,
#  'aren': 10449,
#  'granuals': 19093,
#  'kinston': 16,
#  'finca': 10452,
#  'duplicating': 17,
#  'comprise': 10453,
#  'diego': 18,
#  'jolokia': 6906,
#  'hrs': 20,
#  'phew': 21,
#  'florentine': 22,
#  'depicts': 12140,
#  'tastefully': 23,
#  'embodies': 15581,
#  'avocado': 24,
#  'emeril': 25,
#  'changed': 18052,
#  'furious': 26,
#  'belgian': 27,
#  'dificult': 15582,
#  'cherchies': 10460,
#  'calif': 10461,
#  'kay': 10462,
#  'critique': 185,
#  'calphalon': 13878,
#  'straws': 10464,
#  'eversince': 29,
#  'leafs': 30,
#  'perel': 13226,
#  'explaining': 31,
#  'rejected': 12141,
#  'seltzer': 19053,
#  'rancid': 32,
#  'exploding': 10466,
#  'fatigued': 33,
#  'delta': 10467,
#  'purchasers': 220,
#  'form': 34,
#  'overshadows': 35,
#  'foodies': 36,
#  'qualify': 227,
#  'december': 38,
#  'stockpiled': 19255,
#  'soba': 17348,
#  'trace': 10471,
#  'popcorns': 15584,
#  'ironbeer': 41,
#  'roasting': 42,
#  'distract': 43,
#  'bear': 44,
#  'cinamon': 45,
#  'rico': 46,
#  'ouch': 47,
#  'push': 12992,
#  'aero': 20867,
#  'courtesy': 10475,
#  'picnic': 17350,
#  'requirements': 16620,
#  'highlands': 48,
#  'congrats': 49,
#  'greens': 10477,
#  'dyeing': 10478,
#  'perfectely': 10479,
#  'delish': 20196,
#  'considering': 13881,
#  'southeast': 20445,
#  'edition': 51,
#  'stay': 52,
#  'driveway': 10481,
#  'fischer': 10482,
#  'giggles': 53,
#  'nubs': 54,
#  'biermann': 304,
#  'tamil': 10484,
#  'dice': 55,
#  'appalachian': 56,
#  'squirrel': 15585,
#  'carboard': 18316,
#  'simpsons': 10485,
#  'seeds': 57,
#  'upton': 324,
#  'precaution': 10487,
#  'greatness': 59,
#  'luc': 10488,
#  'externally': 10489,
#  'dolmas': 10490,
#  'sweetly': 60,
#  'talks': 61,
#  'awake': 62,
#  'ace': 10492,
#  'moisturizes': 10493,
#  'broiled': 276,
#  'contains': 64,
#  'scalp': 10494,
#  'is': 14544,
#  'magnificent': 65,
#  'grouper': 372,
#  'reminiscent': 15588,
#  'artificially': 10495,
#  'pt': 10496,
#  'nilla': 10497,
#  'superose': 10498,
#  'gnc': 68,
#  'towelettes': 18870,
#  'rollups': 396,
#  'venezuelan': 19481,
#  'glycerin': 70,
#  'capable': 9149,
#  'ditto': 10500,
#  'overwhelming': 10501,
#  'flyer': 72,
#  'difinitely': 8668,
#  'glasses': 10739,
#  'negril': 73,
#  'lieferung': 74,
#  'wickedly': 10503,
#  'runnier': 11758,
#  'finalize': 14527,
#  'bloomberg': 75,
#  'timei': 76,
#  'bloodstream': 77,
#  'refrigerated': 78,
#  'servers': 20324,
#  'jug': 10505,
#  'began': 79,
#  'ridiculously': 80,
#  'faded': 10507,
#  'tweak': 10508,
#  'tamari': 82,
#  'qt': 10510,
#  'apo': 19105,
#  'able': 83,
#  'sadly': 19979,
#  'wayyy': 10511,
#  'duck': 15589,
#  'winona': 10513,
#  'expensive': 10514,
#  'showcased': 11,
#  'outweigh': 87,
#  'tails': 88,
#  'allot': 12150,
#  'pamula': 89,
#  'attain': 14054,
#  'tiger': 90,
#  'eb': 19176,
#  'successive': 10517,
#  'rootbeer': 10518,
#  'perserve': 10519,
#  'cuba': 91,
#  'hfcs': 10520,
#  'bin': 10521,
#  'complete': 19326,
#  'difificulties': 17357,
#  'trenton': 547,
#  'tamed': 14745,
#  'cosco': 10523,
#  'forgettable': 93,
#  'tucson': 10525,
#  'stapler': 94,
#  'cowboy': 1738,
#  'fireworks': 10528,
#  'responsible': 10529,
#  'cornstarch': 19107,
#  'round': 96,
#  'crowns': 10530,
#  'version': 10531,
#  'afterwords': 18983,
#  'graham': 10532,
#  'improved': 10533,
#  'gloves': 97,
#  'sucre': 10534,
#  'crystallizing': 10535,
#  'knife': 19110,
#  'singles': 99,
#  'platters': 10537,
#  'passionate': 101,
#  'tannin': 102,
#  'movin': 103,
#  'lineup': 104,
#  'gotta': 105,
#  'element': 10539,
#  'ferrara': 10540,
#  'enchanted': 10541,
#  'posted': 10542,
#  'frappacino': 10543,
#  'populate': 106,
#  'buggers': 10545,
#  'nitrites': 109,
#  'flowers': 14095,
#  'b': 110,
#  'eric': 10546,
#  'trashed': 10547,
#  'popocorn': 13975,
#  'winded': 17835,
#  'www': 8675,
#  'sux': 674,
#  'rda': 111,
#  'tarty': 10551,
#  'through': 112,
#  'medifast': 113,
#  'knack': 17825,
#  'successfully': 10553,
#  'big': 114,
#  'justice': 115,
#  'dank': 703,
#  'jerkys': 117,
#  'redmond': 10555,
#  'exellent': 10556,
#  'apple': 716,
#  'marietta': 119,
#  'pure': 120,
#  'altiods': 1744,
#  'scandinavian': 121,
#  'chateau': 122,
#  'lasts': 8679,
#  'satisfactorily': 123,
#  'rejoice': 10560,
#  'dieters': 10562,
#  'antioxidant': 124,
#  'select': 125,
#  'lessening': 126,
#  'reasons': 127,
#  'grapenuts': 128,
#  'dilivery': 13892,
#  'dashed': 129,
#  'meadowood': 130,
#  'baseline': 131,
#  'mannheim': 132,
#  'campus': 10568,
#  'substitues': 796,
#  'jody': 133,
#  'meyers': 134,
#  'extraordinary': 20818,
#  'hardness': 17364,
#  'frazzled': 10570,
#  'dat': 10572,
#  'commonly': 10573,
#  'attendent': 135,
#  'hobby': 136,
#  'persistent': 10574,
#  'mysterious': 137,
#  'rs': 138,
#  'dipotassium': 20243,
#  'unmelted': 12157,
#  'activates': 139,
#  'primitive': 10577,
#  'butterfat': 140,
#  'creamsicles': 12082,
#  'batch': 10579,
#  'processes': 850,
#  'caffene': 10581,
#  'definite': 10456,
#  'goldenberries': 10583,
#  'goodearth': 142,
#  'tilt': 10584,
#  'spreads': 4505,
#  'betty': 143,
#  'disney': 144,
#  'lindt': 145,
#  'snack': 3456,
#  'fattoria': 147,
#  'marmite': 148,
#  'bearito': 149,
#  'unsatisfying': 10588,
#  'notification': 150,
#  'cand': 10589,
#  'wink': 151,
#  'jaded': 10591,
#  'wheezing': 152,
#  'poppyseed': 15216,
#  'acv': 153,
#  'gown': 18685,
#  'member': 10593,
#  'chocovic': 154,
#  'raising': 943,
#  'pachage': 155,
#  'turtle': 156,
#  'sleek': 157,
#  'tricks': 158,
#  'lesst': 159,
#  'uncut': 160,
#  'iron': 10596,
#  'packo': 966,
#  'sanctuary': 10598,
#  'updating': 10599,
#  'exceed': 10600,
#  'klass': 10601,
#  'lured': 17584,
#  'briel': 163,
#  'trip': 164,
#  'vary': 165,
#  'lodge': 10602,
#  'dallas': 10603,
#  'gcholesterol': 12161,
#  'shortbreads': 166,
#  'originate': 10458,
#  'matched': 167,
#  'cork': 13900,
#  'leaving': 168,
#  'wildberry': 169,
#  'mystic': 17730,
#  'princess': 10609,
#  'chocaholic': 170,
#  'smearing': 171,
#  'pepomint': 17367,
#  'freind': 10612,
#  'doen': 19614,
#  'ording': 172,
#  'term': 10614,
#  'torroni': 10615,
#  'coffeemate': 10616,
#  'ons': 173,
#  'bluberry': 174,
#  'surpassses': 10617,
#  'addition': 10618,
#  'boutiques': 1157,
#  'lubricant': 175,
#  'diligent': 10621,
#  'tradional': 176,
#  'rumours': 10622,
#  'dominant': 177,
#  'buttons': 178,
#  'seizure': 179,
#  'control': 180,
#  'alluring': 181,
#  'meltdown': 182,
#  'controling': 10625,
#  'forehead': 15606,
#  'foamy': 10626,
#  'flight': 184,
#  'dried': 10463,
#  'broke': 10627,
#  'deborah': 19122,
#  'developed': 186,
#  'belts': 10629,
#  'scary': 1104,
#  'variances': 188,
#  'six': 189,
#  'lessened': 14729,
#  'oklahoma': 190,
#  'toddler': 10632,
#  'kindergarten': 191,
#  'noni': 13631,
#  'diets': 10633,
#  'extracting': 1139,
#  'butthis': 192,
#  'toxins': 193,
#  'volunteer': 17737,
#  'molino': 20593,
#  'mw': 1751,
#  'steep': 194,
#  'pig': 195,
#  'bb': 8697,
#  'grocery': 196,
#  'rare': 16737,
#  'neither': 10640,
#  'sacchrine': 197,
#  'etci': 3465,
#  'zippy': 198,
#  'straightforward': 199,
#  'parts': 200,
#  'wolff': 20614,
#  'cleanup': 10643,
#  'reheating': 10644,
#  'composted': 201,
#  'dong': 10645,
#  'helps': 10646,
#  'devised': 13082,
#  'ribena': 1200,
#  'guinea': 10648,
#  'insensitive': 202,
#  'resembled': 203,
#  'cassoulet': 16885,
#  'redskins': 1216,
#  'evaporated': 204,
#  'loafs': 13907,
#  'floridian': 10650,
#  'envy': 206,
#  'feast': 207,
#  'exceeded': 10651,
#  'packaging': 208,
#  'jyoti': 12169,
#  'cardomom': 10653,
#  'neighborhood': 10654,
#  'skip': 10655,
#  'attachment': 10656,
#  'lance': 1249,
#  'artery': 856,
#  'repeatable': 210,
#  'display': 211,
#  'noon': 212,
#  'supports': 17634,
#  'fda': 213,
#  'hinges': 214,
#  'coriander': 215,
#  'captures': 10662,
#  'lights': 1285,
#  'adverse': 10664,
#  'rehab': 216,
#  'incentives': 10665,
#  'amaranth': 1300,
#  'sinks': 218,
#  'dread': 1304,
#  'breakage': 10668,
#  'gripe': 219,
#  'gobble': 18805,
#  'serivce': 1315,
#  'palate': 10669,
#  'building': 221,
#  'subdued': 10670,
#  'byrd': 222,
#  'association': 223,
#  'onley': 10672,
#  'purhcase': 12173,
#  'canned': 224,
#  'remarks': 15387,
#  'rec': 1298,
#  'yummmmmmm': 10676,
#  'snapped': 226,
#  'stranded': 10677,
#  'mousses': 12174,
#  'earthiness': 10678,
#  'damson': 37,
#  'maggie': 10679,
#  'lap': 228,
#  'buffalo': 11731,
#  'lest': 10470,
#  'syrup': 10681,
#  'dress': 11312,
#  'katharena': 17380,
#  'son': 20738,
#  'indigestion': 10683,
#  'nutrasweet': 1391,
#  'shows': 232,
#  'camellia': 233,
#  'dept': 1398,
#  'taffys': 13911,
#  'staying': 12618,
#  'sorgham': 15235,
#  'goldfish': 10686,
#  'quik': 234,
#  'bagging': 1433,
#  'superfood': 10688,
#  'thai': 235,
#  'packed': 20424,
#  'sometime': 236,
#  'always': 237,
#  'stopped': 10689,
#  'ahhh': 10690,
#  'assumes': 1451,
#  'legume': 13913,
#  'controlling': 239,
#  'burping': 1459,
#  'maya': 240,
#  'tune': 241,
#  'vegetable': 10472,
#  'retails': 242,
#  'mgr': 10694,
#  'batters': 243,
#  'kernel': 12178,
#  'arevery': 11100,
#  'teriyaki': 244,
#  'twerpz': 245,
#  'rat': 6945,
#  'minor': 15025,
#  'membranes': 248,
#  'purchard': 20321,
#  'prepackaged': 10698,
#  'torture': 1502,
#  'confession': 250,
#  'finely': 251,
#  'fruitabu': 252,
#  'assured': 15616,
#  'fulfill': 19510,
#  'appetizers': 1523,
#  'swig': 1526,
#  'autodelivery': 1533,
#  'supermarket': 12182,
#  'ch': 10703,
#  'celebrity': 1541,
#  'unsurpassed': 256,
#  'excellent': 10704,
#  'gummies': 4834,
#  'cherios': 10474,
#  'honeymooners': 257,
#  'recommendthese': 10705,
#  'purveyor': 258,
#  'circle': 10706,
#  'incoherency': 1583,
#  'realgoodsalt': 10708,
#  'organically': 259,
#  'material': 260,
#  'mantra': 261,
#  'send': 262,
#  'reginald': 263,
#  'relatively': 10709,
#  'canister': 264,
#  'parmesan': 13918,
#  'royale': 12184,
#  'midafternoon': 265,
#  'lib': 266,
#  'ohio': 3932,
#  'fv': 19115,
#  'wafer': 267,
#  'iwill': 268,
#  'yakisoba': 269,
#  'swedish': 13920,
#  'pj': 10713,
#  'charleston': 10714,
#  'establish': 270,
#  'wants': 10715,
#  'moron': 10716,
#  'wishlist': 10717,
#  'disposed': 10718,
#  'microwavable': 16704,
#  'tearoom': 272,
#  'defies': 273,
#  'smoothie': 274,
#  'utility': 4760,
#  'nestl': 19566,
#  'locations': 10720,
#  'forests': 8145,
#  'thought': 10722,
#  'tasted': 18011,
#  'among': 8705,
#  'greasier': 275,
#  'seek': 1697,
#  'therapy': 12787,
#  'droe': 10726,
#  'electrics': 10727,
#  'robbery': 12186,
#  'approves': 277,
#  'durango': 278,
#  'haven': 13921,
#  'colors': 10729,
#  'overpower': 10730,
#  'detract': 10731,
#  'muggy': 279,
#  'jewels': 280,
#  'controversy': 10732,
#  'sweetleaf': 281,
#  'dextrose': 282,
#  'ventures': 14564,
#  'office': 10733,
#  'percent': 283,
#  'pestle': 10735,
#  'gastro': 10736,
#  'bearnaise': 10737,
#  'salada': 4076,
#  'mccutcheons': 284,
#  'perugina': 285,
#  'delcious': 286,
#  'yogurettes': 1764,
#  'scarf': 287,
#  'imposter': 288,
#  'rasin': 289,
#  'riehl': 15146,
#  'drumsticks': 290,
#  'tasteing': 10742,
#  'bod': 10743,
#  'superbly': 291,
#  'kernals': 292,
#  'drumstick': 10744,
#  'canadian': 293,
#  'fudge': 20138,
#  'bhutan': 294,
#  'heavier': 295,
#  'comercially': 296,
#  'hurt': 297,
#  'amp': 10747,
#  'pinto': 10748,
#  'addictively': 298,
#  'toddlers': 5239,
#  'catches': 20462,
#  'answers': 10751,
#  'nigella': 10752,
#  'classic': 300,
#  'uggh': 4411,
#  'babka': 13922,
#  'orlando': 302,
#  'trait': 15421,
#  'image': 7274,
#  'biodegradable': 10756,
#  'shiny': 10483,
#  'cooked': 305,
#  'ener': 306,
#  'opened': 307,
#  'disappoints': 6952,
#  'decrease': 309,
#  'jackson': 310,
#  'licoricey': 12312,
#  'teutonic': 11430,
#  'palestinian': 10758,
#  'cider': 10759,
#  'ya': 311,
#  'carba': 1886,
#  'murray': 312,
#  'leaves': 15999,
#  'amt': 313,
#  'flavenoids': 314,
#  'bonne': 1915,
#  'macchiato': 315,
#  'healthier': 10764,
#  'squared': 316,
#  'graze': 10765,
#  'nightquil': 317,
#  'downgraded': 15805,
#  'girlfriend': 15631,
#  'therein': 17394,
#  'ryvitas': 318,
#  'kit': 319,
#  'alleviate': 320,
#  'wished': 321,
#  'minimal': 10768,
#  'cannisters': 322,
#  'cigars': 16391,
#  'shhhhh': 323,
#  'diy': 10770,
#  'easy': 10486,
#  'lettuce': 13925,
#  'suprisingly': 326,
#  'winey': 327,
#  'departure': 328,
#  'award': 329,
#  'thiese': 330,
#  'ground': 20229,
#  'loads': 331,
#  'flyers': 332,
#  'sleepy': 10778,
#  'implied': 5385,
#  'fisher': 10780,
#  'blaming': 17398,
#  'polar': 10781,
#  'appreciate': 333,
#  'matcha': 334,
#  'rings': 10782,
#  'vacationing': 335,
#  'overflows': 336,
#  'slack': 337,
#  'defy': 10786,
#  'wing': 19564,
#  'mkt': 15894,
#  'airplane': 10787,
#  'designates': 6881,
#  'catalog': 2085,
#  'despondent': 19319,
#  'decorating': 10789,
#  'mi': 10790,
#  'made': 10791,
#  'hediard': 10792,
#  'divvie': 2115,
#  'sugery': 10794,
#  'liver': 340,
#  'dammage': 341,
#  'indicates': 342,
#  'scallions': 10491,
#  'primarily': 343,
#  'unpoped': 19073,
#  'ideal': 10797,
#  'masked': 344,
#  'huge': 345,
#  'rapids': 346,
#  'discretion': 2364,
#  'pace': 347,
#  'heb': 10800,
#  'wissotzky': 10801,
#  'figurine': 2174,
#  'notorious': 10803,
#  'harvested': 348,
#  'hold': 349,
#  'boo': 350,
#  'athens': 351,
#  'circular': 10805,
#  'boosts': 10806,
#  'vibrant': 12266,
#  'requested': 352,
#  'boil': 10807,
#  'defrosted': 20265,
#  'fibroids': 10808,
#  'face': 353,
#  'rewards': 10809,
#  'romance': 354,
#  'glycemic': 355,
#  'gerogia': 2216,
#  'spectacular': 20356,
#  'localally': 17403,
#  'salt': 357,
#  'flatbread': 358,
#  'cocao': 359,
#  'unscented': 12121,
#  'inaccurate': 10811,
#  'diffirent': 10812,
#  'ethiopian': 2247,
#  'opposite': 361,
#  'slimfast': 10815,
#  'pinicky': 10816,
#  'tillamuck': 362,
#  'caramello': 18819,
#  'rehardens': 19145,
#  'dissappointing': 10817,
#  'mojito': 2274,
#  'progam': 14970,
#  'magnesium': 363,
#  'sharwoods': 364,
#  'popsicles': 2281,
#  'garlic': 10820,
#  'destroy': 10821,
#  'extremly': 84,
#  'eve': 366,
#  'consist': 20728,
#  'mixing': 367,
#  'marriott': 368,
#  'tumor': 14189,
#  'meanings': 10825,
#  'workmen': 19148,
#  'grabbed': 369,
#  'contributing': 10827,
#  'divvies': 10828,
#  'fair': 370,
#  'buster': 2321,
#  'compounds': 371,
#  'regain': 66,
#  'suitable': 10831,
#  'husbands': 10832,
#  'lurking': 373,
#  'singapore': 374,
#  'holes': 375,
#  'antiviral': 14715,
#  'nursing': 376,
#  'receive': 377,
#  'popper': 10835,
#  'homeless': 378,
#  'australian': 379,
#  'cities': 380,
#  'bunnies': 10836,
#  'lost': 10837,
#  'trouble': 8721,
#  'nebraska': 20865,
#  'steelcut': 10839,
#  'oblivion': 10840,
#  'she': 18131,
#  'lf': 382,
#  'unnecessarily': 383,
#  'asada': 2392,
#  'noticing': 384,
#  'shopped': 10844,
#  'video': 385,
#  'server': 10845,
#  'landslide': 14588,
#  'leaden': 10846,
#  'bartenders': 10847,
#  'orleans': 10848,
#  'they': 10849,
#  'quilt': 387,
#  'guess': 10851,
#  'reinbursed': 388,
#  'silent': 389,
#  'winnona': 390,
#  'jerked': 391,
#  'bewley': 392,
#  'pizzerias': 393,
#  'unimpressed': 394,
#  'savers': 395,
#  'puffed': 15437,
#  'dum': 10499,
#  'orient': 10854,
#  'ust': 16050,
#  'waikiki': 10855,
#  'gerd': 20508,
#  'specifies': 397,
#  'advertisment': 18809,
#  'char': 3659,
#  'keebler': 398,
#  'mistaking': 18561,
#  'cushioned': 399,
#  'outings': 10858,
#  'antipasto': 2494,
#  'are': 10859,
#  'stabbed': 10860,
#  'forgiving': 10861,
#  'pay': 401,
#  'gobbles': 16166,
#  'froot': 402,
#  'virtues': 10863,
#  'tampering': 2519,
#  'suppliers': 10865,
#  'vick': 403,
#  'hydrated': 10866,
#  'massage': 405,
#  'striking': 406,
#  'separate': 2530,
#  'paula': 407,
#  'genuinely': 408,
#  'cali': 10869,
#  'asparteme': 20583,
#  'wherever': 409,
#  'disks': 410,
#  'bulgur': 411,
#  'skeptic': 412,
#  'dull': 10872,
#  'deliciious': 15639,
#  'holder': 13943,
#  'pumpernickel': 413,
#  'sc': 414,
#  'pursue': 9760,
#  'almost': 416,
#  'hopeing': 417,
#  'ginko': 418,
#  'introduces': 419,
#  'tooth': 10878,
#  'procope': 10879,
#  'milka': 16841,
#  'attendant': 420,
#  'paks': 421,
#  'hawaiian': 10881,
#  'monin': 19880,
#  'dynamic': 2614,
#  'carrageenan': 12206,
#  'maruchan': 2618,
#  'clusters': 17326,
#  'occupy': 10884,
#  'valdosta': 422,
#  'ldl': 10885,
#  'miss': 10886,
#  'mush': 10887,
#  'comparably': 423,
#  'loud': 12210,
#  'cranberries': 10889,
#  'substance': 13948,
#  'ingenuitea': 424,
#  'patent': 10890,
#  'horde': 16372,
#  'invisible': 2655,
#  'glutton': 10892,
#  'satisifies': 10893,
#  'dieting': 16156,
#  'douglas': 10894,
#  'oliver': 425,
#  'relax': 19157,
#  'lesaffre': 426,
#  'joray': 10896,
#  'barbera': 1816,
#  'rail': 428,
#  'pastilles': 429,
#  'tuaca': 430,
#  'helper': 19532,
#  'putrid': 431,
#  'dermatitis': 10897,
#  'parcel': 10898,
#  'preach': 10899,
#  'vastly': 10900,
#  'ripped': 10901,
#  'taurine': 10902,
#  'didnot': 432,
#  'pulpy': 433,
#  'indulgence': 10903,
#  'popcorm': 434,
#  'fallon': 435,
#  'yeast': 10504,
#  'phased': 436,
#  'pawn': 2738,
#  'sunridge': 439,
#  'remedies': 10905,
#  'breeze': 15644,
#  'mow': 440,
#  'flavorfull': 10907,
#  'delicius': 10908,
#  'gimmicky': 19161,
#  'cal': 10909,
#  'maryland': 14325,
#  'nutritionists': 10910,
#  'platic': 441,
#  'avalible': 19982,
#  'sand': 443,
#  'margerine': 444,
#  'jus': 445,
#  'techniques': 10912,
#  'cars': 446,
#  'soit': 447,
#  'paramount': 448,
#  'fairway': 449,
#  'scenario': 10913,
#  'agriculture': 10914,
#  'welcomed': 17419,
#  'sending': 20302,
#  'lowers': 15138,
#  'incentive': 10915,
#  'tough': 451,
#  'appointments': 10916,
#  'weakest': 10917,
#  'alcohols': 10918,
#  'ready': 10919,
#  'amplifies': 10506,
#  'statements': 17046,
#  'dominican': 10920,
#  'freen': 452,
#  'hummingbird': 20760,
#  'eraser': 2851,
#  'decent': 13154,
#  'shaded': 454,
#  'lounge': 2857,
#  'thm': 20278,
#  'resplendent': 456,
#  'wheni': 10924,
#  'antacid': 457,
#  'outer': 458,
#  'motivation': 459,
#  'gettting': 460,
#  'responsibly': 461,
#  'continue': 10927,
#  'atta': 462,
#  'orgasm': 6980,
#  'squeezing': 464,
#  'abscessed': 15131,
#  'grave': 465,
#  'flake': 20659,
#  'barrels': 466,
#  'wat': 467,
#  'supplements': 10928,
#  'compels': 2922,
#  'timley': 10929,
#  'release': 10930,
#  'highy': 469,
#  'howards': 10931,
#  'delite': 470,
#  'davidoff': 5443,
#  'beetlegeuse': 14186,
#  'vinegars': 10934,
#  'youstephanie': 471,
#  'sweetarts': 472,
#  'krinkle': 473,
#  'tread': 10935,
#  'industry': 474,
#  'das': 20289,
#  'cured': 475,
#  'walked': 476,
#  'involved': 19754,
#  'ecological': 13191,
#  'snowy': 477,
#  'optimum': 19925,
#  'mad': 478,
#  'supple': 10937,
#  'fuji': 479,
#  'coffeemaker': 480,
#  'rotated': 481,
#  'stacey': 10941,
#  'expanded': 483,
#  'barton': 484,
#  'discoverd': 485,
#  'expedited': 19168,
#  'kretschmer': 10944,
#  'whyyyy': 19732,
#  'haves': 486,
#  'geared': 10945,
#  'primula': 3029,
#  'cherish': 19924,
#  'crackling': 488,
#  'peets': 10946,
#  'cherry': 4245,
#  'reset': 489,
#  'proportion': 10948,
#  'hich': 490,
#  'heh': 3055,
#  'amore': 10951,
#  ...}

# %%
## map each sentence to a vector of words:
sentence_vecs = np.array(df["text_adj"].apply(lambda x: create_sentence_vectors(x, vocab)).tolist())

# %%
sentence_vecs
# Out:
# array([[ 1346, 17301, 14958, ..., 15719, 15719, 15719],
#        [12559, 14122,  5154, ..., 15719, 15719, 15719],
#        [15329,  2878, 14222, ..., 15719, 15719, 15719],
#        ...,
#        [  926, 11568,  1346, ..., 15719, 15719, 15719],
#        [ 4998, 14544, 12670, ..., 15719, 15719, 15719],
#        [ 8989,  4080, 17301, ..., 15719, 15719, 15719]])

# %% [markdown]
# ## Need to adjust here!!!

# %%
label_vecs = np.array(df.negative.tolist())

# %%
## train-valid-test split
train_dataset, test_dataset, train_labels, test_labels = \
                            train_test_split(sentence_vecs, label_vecs, test_size=0.3, random_state=0)
test_dataset, valid_dataset, test_labels, valid_labels = \
                            train_test_split(test_dataset, test_labels, test_size=0.33, random_state=0)

# %%
print ("Size of train set: %s" % len(train_dataset))
print ("Size of test set: %s" % len(test_dataset))
print ("Size of validation set: %s" % len(valid_dataset))
# Out:
# Size of train set: 344813
# Size of test set: 99010
# Size of validation set: 48767

# %%
train_dataset, train_labels
# Out:
# (array([[32640, 31343, 12304, ..., 16217, 16217, 16217],
#         [30686, 37776,  5908, ..., 16217, 16217, 16217],
#         [16211, 32635, 48640, ..., 16217, 16217, 16217],
#         ...,
#         [32635, 45394,  6363, ..., 16217, 16217, 16217],
#         [ 6363, 21159, 30569, ..., 16217, 16217, 16217],
#         [27385, 19708, 15740, ..., 16217, 16217, 16217]]),
#  array([0, 1, 0, ..., 0, 0, 0]))

# %% [markdown]
# ## Ready for tensorflow!

# %%
SEQ_LENGTH = 200
BATCH_SIZE = 50
NUM_LABELS = 2

VOCAB_SIZE = len(vocab)
EMBED_SIZE = 128

FILTER_SIZE_1 = 3
FILTER_SIZE_2 = 4
FILTER_SIZE_3 = 5
NUM_FILTERS = 128

keep_prob = 0.8

tf_train_dataset = tf.placeholder(tf.int32, shape=(BATCH_SIZE, SEQ_LENGTH))
tf_train_labels = tf.placeholder(tf.int32, shape=(BATCH_SIZE))
tf_valid_dataset = tf.constant(valid_dataset) 
tf_test_dataset = tf.constant(test_dataset)

# Keeping track of l2 regularization loss (optional)
#l2_loss = tf.constant(0.0)

## Embedding layer

embed_weigths = tf.Variable(tf.random_uniform([VOCAB_SIZE, EMBED_SIZE], -1.0, 1.0))
    
## Convolutional layers
## Change to True if run again
with tf.variable_scope("vars", reuse = None):
    
    conv1_weights = tf.get_variable("conv1_w", shape=[FILTER_SIZE_1, EMBED_SIZE, 1, NUM_FILTERS],\
                                                    initializer=tf.contrib.layers.xavier_initializer_conv2d())
    conv1_biases = tf.Variable(tf.constant(0.1, shape=[NUM_FILTERS]), name = "conv1_b")

    conv2_weights = tf.get_variable("conv2_w", shape=[FILTER_SIZE_2, EMBED_SIZE, 1, NUM_FILTERS],\
                                                    initializer=tf.contrib.layers.xavier_initializer_conv2d())
    conv2_biases = tf.Variable(tf.constant(0.1, shape=[NUM_FILTERS]), name = "conv2_b")

    conv3_weights = tf.get_variable("conv3_w", shape=[FILTER_SIZE_3, EMBED_SIZE, 1, NUM_FILTERS],\
                                                    initializer=tf.contrib.layers.xavier_initializer_conv2d())
    conv3_biases = tf.Variable(tf.constant(0.1, shape=[NUM_FILTERS]), name = "conv3_b")

## Fully connected layer

    fc1_weights = tf.get_variable("fc1_w", shape=[3*NUM_FILTERS, NUM_LABELS],\
                                                initializer=tf.contrib.layers.xavier_initializer())
    fc1_biases = tf.Variable(tf.constant(0.1, shape=[NUM_LABELS]), name = "fc1_b")

# Model:
def model(data, keep_prob = keep_prob): 
    
    ## Embedding layer
    ## input shape:[BATCH_SIZE, SEQ_LENGTH]
    ## output shape: [BATCH_SIZE, SEQ_LENGTH, EMBED_SIZE, 1]
    
    with tf.device('/cpu:0'), tf.name_scope("embedding"):    
        embed_chars = tf.nn.embedding_lookup(embed_weigths, data)
        embed_chars = tf.expand_dims(embed_chars, -1)
    
    ## Conv1+ReLu+max pooling
    ## input shape: [BATCH_SIZE, SEQ_LENGTH, EMBED_SIZE, 1]
    ## output shape: [BATCH_SIZE, 1, 1, NUM_FILTERS]
    
    conv1 = tf.nn.conv2d(embed_chars, conv1_weights, strides=[1, 1, 1, 1], padding="VALID")
    relu1 = tf.nn.relu(tf.nn.bias_add(conv1, conv1_biases))
    pool1 = tf.nn.max_pool(relu1, ksize=[1, SEQ_LENGTH-FILTER_SIZE_1+1, 1, 1],
                           strides=[1, 1, 1, 1], padding='VALID')
    ## Conv2+ReLu+max pooling
    ## input shape: [BATCH_SIZE, SEQ_LENGTH, EMBED_SIZE, 1]
    ## output shape: [BATCH_SIZE, 1, 1, NUM_FILTERS]
    
    conv2 = tf.nn.conv2d(embed_chars, conv2_weights, strides=[1, 1, 1, 1], padding="VALID")
    relu2 = tf.nn.relu(tf.nn.bias_add(conv2, conv2_biases))
    pool2 = tf.nn.max_pool(relu2, ksize=[1, SEQ_LENGTH-FILTER_SIZE_2+1, 1, 1],
                           strides=[1, 1, 1, 1], padding='VALID')
    
    ## Conv3+ReLu+max pooling
    ## input shape: [BATCH_SIZE, SEQ_LENGTH, EMBED_SIZE, 1]
    ## output shape: [BATCH_SIZE, 1, 1, NUM_FILTERS]
    
    conv3 = tf.nn.conv2d(embed_chars, conv3_weights, strides=[1, 1, 1, 1], padding="VALID")
    relu3 = tf.nn.relu(tf.nn.bias_add(conv3, conv3_biases))
    pool3 = tf.nn.max_pool(relu3, ksize=[1, SEQ_LENGTH-FILTER_SIZE_3+1, 1, 1],
                           strides=[1, 1, 1, 1], padding='VALID')
    
    ## Combine pooled features + flatten
    ## input shape: [BATCH_SIZE, 1, 1, NUM_FILTERS]
    ## output shape: [BATCH_SIZE, 3, 1, 1, NUM_FILTERS]
    
    pooled_outputs = [pool1, pool2, pool3]
    h_pool = tf.concat(pooled_outputs,3)
    h_pool_flat = tf.reshape(h_pool, [-1, NUM_FILTERS*3])
    h_pool_flat = tf.nn.dropout(h_pool_flat, keep_prob)
    
    ## Fully connected layer
    return tf.matmul(h_pool_flat, fc1_weights) + fc1_biases  
  
# Training computation:
logits = model(tf_train_dataset)
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
  
# Optimizer:
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

# with tf.name_scope("output"):
#            W = tf.get_variable(
#                "W",
#                shape=[num_filters_total, num_classes],
#                initializer=tf.contrib.layers.xavier_initializer())
#            b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
#            l2_loss += tf.nn.l2_loss(W)
#            l2_loss += tf.nn.l2_loss(b)
#            self.scores = tf.nn.xw_plus_b(self.h_drop, W, b, name="scores")
#            self.predictions = tf.argmax(self.scores, 1, name="predictions")
#
#        # CalculateMean cross-entropy loss
#        with tf.name_scope("loss"):
#            losses = tf.nn.softmax_cross_entropy_with_logits(logits=self.scores, labels=self.input_y)
#            self.loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

# %%
## remove objects from memory
del word_dist
del word_lookup

# %% [markdown]
# **Predictions for the training, validation, and test data**

# %%
train_prediction = tf.nn.softmax(logits)
valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %% [markdown]
# ## Train model and report accuracy

# %%
NUM_ITERATIONS = 1001

step = []
pred = []
loss_minibatch = []
accuracy_minibatch = []
accuracy_valid = []

logs_path = '../tensorflow_logs/example'

with tf.Session() as session:
    tf.global_variables_initializer().run()
    
    # op to write logs to Tensorboard
    summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())
    
    for i in range(NUM_ITERATIONS):
        offset = (i * BATCH_SIZE) % (train_labels.shape[0] - BATCH_SIZE)
        batch_data = train_dataset[offset:(offset + BATCH_SIZE), :]
        batch_labels = train_labels[offset:(offset + BATCH_SIZE)]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict) 
        
        if (i % 200 == 0): ## info will be printed every 1000th time
            #predictions = np.argmax(predictions, 1)
            step.append(i)
            print("Minibatch loss at step %d: %f" % (i, l))
            loss_minibatch.append(l)
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            accuracy_minibatch.append(accuracy(predictions, batch_labels))
            #print("Minibatch f1 score: %.1f%%" % f1_score(predictions, batch_labels))
            #accuracy_minibatch.append(f1_score(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))    
            accuracy_valid.append(accuracy(valid_prediction.eval(), valid_labels))
            #print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))    
            #accuracy_valid.append(accuracy(valid_prediction.eval(), valid_labels))
            
    print("\nTest accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
    
    #save_path = saver.save(session, "../models/SVHN_MODEL.ckpt")
    #print("Model saved in file: %s" % save_path)
    
    #pred.append(test_prediction.eval(), 1)
    
    print("Run the command line:\n" \
          "--> tensorboard --logdir=/tmp/tensorflow_logs " \
          "\nThen open http://172.26.179.29:6006/ into your web browser")

#pred = pred[0]

#def accuracy(predictions, labels):
#    return (100.0 * np.sum(np.argmax(predictions, 1) == labels) / predictions.shape[0])
# Out:
# Minibatch loss at step 0: 0.718236
# Minibatch accuracy: 46.0%
# Validation accuracy: 63.9%
# Validation accuracy: 64.1%
# Minibatch loss at step 200: 0.391989
# Minibatch accuracy: 84.0%
# Validation accuracy: 84.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 400: 0.283092
# Minibatch accuracy: 90.0%
# Validation accuracy: 85.1%
# Validation accuracy: 85.0%
# Minibatch loss at step 600: 0.260687
# Minibatch accuracy: 90.0%
# Validation accuracy: 85.1%
# Validation accuracy: 85.1%
# Minibatch loss at step 800: 0.201020
# Minibatch accuracy: 94.0%
# Validation accuracy: 85.9%
# Validation accuracy: 86.0%
# Minibatch loss at step 1000: 0.390799
# Minibatch accuracy: 84.0%
# Validation accuracy: 86.9%
# Validation accuracy: 86.7%
#
# Test accuracy: 86.8%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-58d2514b4026> in <module>()
#      41     #print("Model saved in file: %s" % save_path)
#      42
# ---> 43     pred.append(test_prediction.eval(), 1)
#      44
#      45 pred = pred[0]
#
# TypeError: append() takes exactly one argument (2 given)

# %%
pred
# Out:
# []

# %%
print precision_score(test_labels, pred)
print recall_score(test_labels, pred)
print accuracy_score(test_labels, pred)
print f1_score(test_labels, pred)
confusion_matrix(test_labels, pred)
# Out:
# 0.820322443784
# 0.628167641326
# 0.921990049751
# 0.711499540018
# array([[33197,   847],
#        [ 2289,  3867]])

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(step[1:len(step)],loss_minibatch[1:len(step)])
plt.xlabel('Number of iterations')
plt.ylabel('Loss')
plt.title('Loss training set per number of iterations')

plt.subplot(1, 2, 2)
plt.plot(step[1:len(step)],accuracy_minibatch[1:len(step)], label = 'Training accuracy')
plt.plot(step[1:len(step)],accuracy_valid[1:len(step)], label = 'Validation accuracy')
plt.legend(loc = 0)
plt.xlabel('Number of iterations')
plt.ylabel('Accuracy')
plt.title('Accuracy training vs vailadation set per number of iterations')
