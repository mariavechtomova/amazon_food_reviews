# %%
import pandas as pd
from helpers import *

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from nltk import FreqDist
import operator
import numpy as np

from sklearn.model_selection import train_test_split

import pickle
# Out:
# /home/vecht499/.local/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# ## Load dataset & process it

# %%
df = pd.read_csv("../data/Reviews.csv")
df.columns = map(lambda x: x.lower(), df.columns)

# %%
## score distribution
plt.figure(figsize=(15,8))
sns.kdeplot(df.score, shade=True)

# %%
## remove neutral reviews
df=df[df.score!=3].copy()

# %%
df = df[pd.notnull(df.text)].reset_index(drop=True).copy()

# %%
df["text"] = df["text"].apply(lambda x: cleanData(x))
df["text_length"] = df["text"].apply(lambda x: getSentenceLength(x))

## create negative dummy var
df["negative"] = df["score"].apply(lambda x: 1 if x<3 else 0)

## create numerical categories
df["cat1_num"] = df['cat1'].astype('category').cat.codes
df["cat2_num"] = df['cat2'].astype('category').cat.codes

# %%
## review length distribution
plt.figure(figsize=(15,8))
sns.kdeplot(df.text_length, shade=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348617 entries, 0 to 1348616
# Data columns (total 13 columns):
# productid      1348617 non-null object
# title          1348162 non-null object
# userid         1348617 non-null object
# helpfulness    1348617 non-null object
# score          1348617 non-null float64
# text           1348617 non-null object
# cat1           1348617 non-null object
# cat2           1348617 non-null object
# cat3           1348617 non-null object
# text_length    1348617 non-null int64
# negative       1348617 non-null int64
# cat1_num       1348617 non-null int8
# cat2_num       1348617 non-null int8
# dtypes: float64(1), int64(2), int8(2), object(8)
# memory usage: 115.8+ MB

# %%
## remove reviews with length more than 100
df = df[df.text_length<=100].copy()
## if length of a review is shorter than 100; fill it in with placeholer words
df["text_adj"] = df["text"].apply(lambda x: add_placeholders(x,100))

# %%
df.head(2)
# Out:
#     productid                                        title          userid  \
# 0  B0000DF3IX                      Paprika Hungarian Sweet  A244MHL2UN2EYL
# 1  B0002QF1LK  Quaker Honey Graham Oh's 10.5 oz - (6 pack)  A3FL7SXVYMC5NR
#
#   helpfulness  score                                               text  \
# 0         0/0    5.0  while in hungary we were given a recipe for hu...
# 1         3/3    5.0  without a doubt i would recommend this wholeso...
#
#                      cat1             cat2                cat3  text_length  \
# 0   grocery  gourmet food            herbs  spices  seasonings           32
# 1   grocery  gourmet food  breakfast foods             cereals           38
#
#    negative  cat1_num  cat2_num  \
# 0         0         2        35
# 1         0         2        10
#
#                                             text_adj
# 0  while in hungary we were given a recipe for hu...
# 1  without a doubt i would recommend this wholeso...

# %%
## create word count dictionary for all reviews
word_dist = FreqDist()
for s in df.text_adj:
    word_dist.update(s.split())

## replace rare words (occur only once)
words_to_replace = [k for k, v in word_dist.items() if v == 1]

word_lookup = {}
for word in word_dist.keys():
    if word in words_to_replace:
        word_lookup[word] = "rareword"
    else:
        word_lookup[word] = word

def replace_words(strg, words_to_replace):
    line = strg.split()
    line = [word_lookup[x] for x in line]
    result = ' '.join(line)
    return result

df["text_adj"] = df["text_adj"].apply(lambda x: replace_words(x, words_to_replace))

# %%
## create word count dictionary for all reviews
word_dist = FreqDist()
for s in df.text_adj:
    word_dist.update(s.split())

## take a look at dictionary
sorted_x = sorted(word_dist.items(), key=operator.itemgetter(1))
print(sorted_x)
# Out:
# [('roomin', 2), ('refuring', 2), ('snookered', 2), ('greyi', 2), ('emperial', 2), ('flims', 2), ('shocky', 2), ('kronch', 2), ('duromed', 2), ('cora', 2), ('drawin', 2), ('contestents', 2), ('floppily', 2), ('orderedthe', 2), ('denatonium', 2), ('takecare', 2), ('mbt', 2), ('hoagie', 2), ('schwan', 2), ('forclose', 2), ('timeto', 2), ('samule', 2), ('oldgranddaughter', 2), ('gta', 2), ('amazonit', 2), ('llook', 2), ('placental', 2), ('wiould', 2), ('eveing', 2), ('morgann', 2), ('amande', 2), ('placei', 2), ('hevy', 2), ('timesbetter', 2), ('mortally', 2), ('oxbile', 2), ('liceguard', 2), ('ialways', 2), ('pnk', 2), ('expectationsthe', 2), ('seaker', 2), ('untili', 2), ('tooties', 2), ('inagination', 2), ('chiuhuahua', 2), ('propbably', 2), ('scuzzy', 2), ('extortionist', 2), ('sinnamon', 2), ('vearied', 2), ('dobbler', 2), ('proglides', 2), ('umbrealla', 2), ('dind', 2), ('flowcons', 2), ('toofbrush', 2), ('vitrex', 2), ('appriciated', 2), ('tgo', 2), ('oticon', 2), ('descendant', 2), ('youngerand', 2), ('enunciates', 2), ('cchristmas', 2), ('snes', 2), ('cubei', 2), ('hensvik', 2), ('resonibly', 2), ('goodthird', 2), ('ealily', 2), ('guaifenisen', 2), ('thialand', 2), ('exhcange', 2), ('haaaaaaaaaa', 2), ('wasan', 2), ('tambem', 2), ('discontine', 2), ('bely', 2), ('comination', 2), ('mariebelle', 2), ('poky', 2), ('reservor', 2), ('goit', 2), ('therap', 2), ('mountian', 2), ('sermon', 2), ('gettinga', 2), ('usingyour', 2), ('ablilities', 2), ('hydrophobic', 2), ('mmmmmmmmmmmmmmm', 2), ('clearjel', 2), ('forgave', 2), ('allgery', 2), ('thnking', 2), ('dryout', 2), ('shippiong', 2), ('tmd', 2), ('eggos', 2), ('discrption', 2), ('notget', 2), ('aquasana', 2), ('adequacy', 2), ('jammy', 2), ('magnificantion', 2), ('deeep', 2), ('recipees', 2), ('productmakes', 2), ('coda', 2), ('decibals', 2), ('dogi', 2), ('merl', 2), ('lbd', 2), ('immatation', 2), ('superfresh', 2), ('outrageouswww', 2), ('flavius', 2), ('evenning', 2), ('heretofore', 2), ('manufactorer', 2), ('tobut', 2), ('plue', 2), ('shameeee', 2), ('geth', 2), ('lita', 2), ('devuelvan', 2), ('tacchycardia', 2), ('nextgen', 2), ('peppier', 2), ('likeaveeno', 2), ('luky', 2), ('rued', 2), ('lapresia', 2), ('mediterranee', 2), ('orderring', 2), ('shubunkin', 2), ('chapstic', 2), ('tournent', 2), ('estimulada', 2), ('evitaminstore', 2), ('exemplified', 2), ('trew', 2), ('entretienen', 2), ('intenna', 2), ('fith', 2), ('separeted', 2), ('creualty', 2), ('responda', 2), ('rythums', 2), ('favaorite', 2), ('reivewer', 2), ('pummel', 2), ('deliverable', 2), ('penguine', 2), ('productplease', 2), ('autodrop', 2), ('paguei', 2), ('nk', 2), ('zx', 2), ('leavers', 2), ('accesseries', 2), ('sods', 2), ('flatmate', 2), ('waterpiking', 2), ('recommanding', 2), ('armatron', 2), ('inchers', 2), ('rehabilitator', 2), ('hetold', 2), ('intence', 2), ('estaremos', 2), ('exlusivley', 2), ('henkel', 2), ('montpelier', 2), ('verdadera', 2), ('macdowell', 2), ('catsears', 2), ('duwop', 2), ('clogune', 2), ('masterpice', 2), ('corona', 2), ('trimmmers', 2), ('necrofear', 2), ('borni', 2), ('aqauarium', 2), ('elemento', 2), ('ggc', 2), ('profesor', 2), ('chukar', 2), ('debriding', 2), ('wiimote', 2), ('miseries', 2), ('beefspoons', 2), ('quanch', 2), ('dild', 2), ('fuzors', 2), ('odoriferous', 2), ('johanson', 2), ('carbamide', 2), ('propiedad', 2), ('thalium', 2), ('engourged', 2), ('shreiks', 2), ('dynaflex', 2), ('flashbackfever', 2), ('elepander', 2), ('staind', 2), ('ansel', 2), ('restop', 2), ('nlt', 2), ('allpine', 2), ('undertaken', 2), ('moai', 2), ('pumices', 2), ('presso', 2), ('kcals', 2), ('deshedders', 2), ('kabucha', 2), ('prevoius', 2), ('sorprise', 2), ('pomerainan', 2), ('lotins', 2), ('happenning', 2), ('mithril', 2), ('backword', 2), ('multiprotection', 2), ('persuing', 2), ('waaaaayyy', 2), ('stax', 2), ('bluffers', 2), ('comparason', 2), ('ieuwwwwwww', 2), ('yeilds', 2), ('ays', 2), ('avatrol', 2), ('yoyojam', 2), ('ganaden', 2), ('antigas', 2), ('frizy', 2), ('juvenille', 2), ...

# %%
vocab = {}
for e,y in enumerate(word_dist.keys()):
    vocab[y]=e

# %%
## map each sentence to a vector of words:
df["sentence_vecs"] = df["text_adj"].apply(lambda x: create_sentence_vectors(x, vocab))

# %%
df_full = df.copy()
df = df.sample(n=200000, random_state=0).copy()

# %% [markdown]
# ## Train / test / valid split + create pickles

# %%
train, test = train_test_split(df_full, test_size = 0.3, random_state = 0)
test, valid = train_test_split(test, test_size = 0.33, random_state = 0)
full_df = {'train': train, 'test': test, 'valid': valid}

# %%
train, test = train_test_split(df, test_size = 0.3, random_state = 0)
test, valid = train_test_split(test, test_size = 0.33, random_state = 0)
sample_df = {'train': train, 'test': test, 'valid': valid}

# %%
result = {'full_df': full_df, 'sample_df': sample_df}

# %%
with open('../data/prepared_data.pickle', 'wb') as data:
    pickle.dump(result, data)
